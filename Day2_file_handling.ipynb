# %%
with open(r"D:\data_engineering_roadmap\python-practice\students.txt", "r") as file:
    marks = []

    for line in file:
        name, mark = line.strip().split(",")
        marks.append(float(mark))

print("Average:", sum(marks)/len(marks))
print("Highest:", max(marks))
print("Lowest:", min(marks))
# Out:
# Average: 85.75
# Highest: 92.0
# Lowest: 78.0

# %%
import csv

employees = []
salaries = []

# Read the CSV file
with open("employees.csv", "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        name = row["name"]
        salary = int(row["salary"])

        employees.append({"name": name, "salary": salary})
        salaries.append(salary)

# Calculate average salary
average_salary = sum(salaries) / len(salaries)

# Find highest paid employee
highest_paid = max(employees, key=lambda emp: emp["salary"])

# Count employees
employee_count = len(employees)

# Display results
print("Average Salary:", average_salary)
print("Highest Paid Employee:", highest_paid["name"])
print("Highest Salary:", highest_paid["salary"])
print("Total Employees:", employee_count)
print(salaries)
print(employees)
# Out:
# Average Salary: 65000.0
# Highest Paid Employee: David
# Highest Salary: 80000
# Total Employees: 4
# [50000, 70000, 60000, 80000]
# [{'name': 'Alice', 'salary': 50000}, {'name': 'Bob', 'salary': 70000}, {'name': 'Charlie', 'salary': 60000}, {'name': 'David', 'salary': 80000}]
